# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori 
import time

# %%
trans_data = pd.read_csv('../dataset/store_data_apriori.csv', header=None)

# %%
trans_data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
trans_data.shape
# Out:
# (7501, 20)

# %%
records = []  
for i in range(0, 7501):  
    records.append([str(trans_data.values[i,j]) for j in range(0, 20)])

# %%
t1 = time.time()
association_rules = apriori(records, min_support=0.0056, min_confidence=0.2, min_lift=1.2, max_length=3)  
association_results = list(association_rules) 
print('Total time taken for rule mapping:', time.time() - t1)
# Out:
# Total time taken for rule mapping: 0.6054794788360596

# %%
print(len(association_results))
# Out:
# 454

# %%
association_results[0]
# Out:
# RelationRecord(items=frozenset({'chocolate', 'almonds'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'chocolate'}), confidence=0.29411764705882354, lift=1.7950988369310295)])

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[1] + " is bought when -> " + items[0]+'is bought', items)
    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: almonds is bought when -> chocolateis bought
# Support: 0.005999200106652446
# Confidence: 0.29411764705882354
# Lift: 1.7950988369310295
# ...
# Rule: eggs is bought when -> almondsis bought
# Support: 0.006532462338354886
# Confidence: 0.3202614379084967
# Lift: 1.7821076007059597
# ...
# Rule: almonds is bought when -> mineral wateris bought
# Support: 0.007598986801759766
# Confidence: 0.37254901960784315
# Lift: 1.5629139799096374
# ...
# Rule: almonds is bought when -> spaghettiis bought
# Support: 0.005999200106652446
# Confidence: 0.29411764705882354
# Lift: 1.6892622286280516
# ...
# Rule: avocado is bought when -> chocolateis bought
# Support: 0.007065724570057326
# Confidence: 0.212
# Lift: 1.293907241659886
# ...
# Rule: avocado is bought when -> french friesis bought
# Support: 0.007998933475536596
# Confidence: 0.24000000000000002
# Lift: 1.4042433697347896
# ...
# Rule: milk is bought when -> avocadois bought
# Support: 0.007465671243834155
# Confidence: 0.22399999999999998
# ...
